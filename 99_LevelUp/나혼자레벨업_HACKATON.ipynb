# %% [markdown]
# # 해커톤 전략 로드맵 - 지방 재정 절약 App
#
# ## 1. 핵심 컨셉 정리
# - **주제**: 지역균형 발전을 위한 사회 서비스 개발
# - **앱 컨셉**: 낭비되는 지방 예산을 분석하고, 절약 가능한 부분을 찾아 의미 있는 사업(출산장려금 등)에 재투자할 수 있도록 공무원을 보조하는 서비스
# - **주요 기능**
#   - 공공 데이터 기반 세금 사용 분석 (ML/DL 활용)
#   - 낭비 예측/탐지 기능
#   - 시각화 대시보드 (지역별/사업별 비교)
#   - 대안 제안 시스템 (예: 이 예산이면 출산장려금 몇 명에게 지급 가능)
#
#
# &nbsp;
# ---
#
# ## 2. 기술 스택 제안
#
# | 분야       | 기술 스택                            |
# |------------|---------------------------------------|
# | 백엔드     | FastAPI / Django REST                |
# | 데이터베이스 | PostgreSQL + PostGIS (공간 데이터)   |
# | ML/DL      | XGBoost, LightGBM, LSTM, PyTorch 등  |
# | 시각화     | Plotly, Seaborn, Streamlit / Vue.js |
# | 프론트     | Flutter / React Native                |
# | 배포       | Docker + AWS (EC2, S3, RDS) / Render  |
#
#
# **아마 배포는 Docker+AWS로 할 듯?**
#
#
# &nbsp;
#
# ## 📊 3. 활용 데이터 소스
#
# - 지방재정 통합공개시스템 / 공공데이터포털
# - 지방행정 인허가 데이터 개방 시스템
# - KOSIS 국가통계포털 (지역 경제, 출산율 등)
# - 각 지자체 오픈 API
#
#
#
# ## 🤖 4. ML/DL 적용 아이디어
#
# - **이상 지출 탐지**: 예산 집행 내역에서 비정상적인 사용 감지
# - **사업 효율성 분석**: 예산 대비 효과 분석 (예: 출산율 향상 vs 투자 금액)
# - **예산 시뮬레이션**: 가상 재배분 결과 예측 (시나리오 생성)
#
#
#
# ## 📱 5. 앱 기능 구조 (예시)
#
# - 사용자 유형별 로그인 (공무원 / 시민 등)
# - 지역 및 사업 선택 후 집행 내역 분석
# - 절약 가능성 분석 리포트 제공
# - 대안 제시 및 대시보드 시각화
# - 의견 수렴 기능 (시민 참여형)
#
#
#
# ## 🏆 6. 수상 전략 포인트
#
# - 정책적 메시지 강조: “지방 살림 혁신 도구”
# - 공공 데이터 활용 → 신뢰성과 실현 가능성 강조
# - 시각화에 집중하여 이해관계자의 직관적 해석 유도
# - 국민 의견 수렴 기능으로 참여 민주주의 실현
#
#
#
# ## ⏳ 일정 체크리스트
#
# | 기간       | 내용                           |
# |------------|--------------------------------|
# | ~6월 27일   | 기획서 작성 및 참가 신청        |
# | 6/28 ~ 7/15 | 데이터 수집 및 전처리, 모델 설계 |
# | 7/16 ~ 7/31 | 프론트/백엔드 개발, 시각화 구현 |
# | 8/1 ~ 8/10  | 통합 테스트, 발표자료 제작       |
# | 8월 11일    | 최종 결과물 제출                |

# %% [markdown]
# # 참가팀 정보
#
# ## 1. 팀 소개글
# 우리는 지역균형 발전을 위한 기술 기반의 사회문제 해결에 도전하는 팀입니다.
#
#
# (특히 지역의 균형적인 발전을 위해 사용되는 예산의 효율을 높임과 예산 절약으로 보다 의미있는 복지 정책(출산 장려금, 창업지원금 등)에 재투자될 수 있는 구조를 만들고자 합니다. 공공 데이터기반의 AI분석과 데이터 시각화를 통해 공무원의 업무를 지원하는 스마트앱서비스를 목표로 하고 있습니다.)
# * 이 내용은 참가신청서 양식에 들어갈 내용임. 실제 웹사이트에 올리는 팀소개글에는 등장 X
#
# ## 2. 팀명
# **유연한사고**
# (팀명 정해야댐.)
#
# ## 3. 참가과제
# **지정과제**
#
# ## 4. 아이디어 명칭
# **RE:Budget 지방재정 절약분석을 통한 재정 혁신 플랫폼**
# (RE:ZERO 애니에서 영감을 받음.ㅋㅋ)
# ## 5. 아이디어 소개
#
# ### 1. 추진배경
# 지방 발전을 위한 예산은 다양한 사업에 투자되고 있지만, 일부는 사업이익의 최소치에 도달하지 못하거나, 비효율적으로 사용되는 사례가 존재함.(이건 검색해서 알아봐야할 내용 ㅇㅇ). 특히 인구 감소, 저출산 문제 해결 등 시급한 과제들에 자원이 집중되기 위해선 최소이익에 도달하지 못하는 재정의 절약이 우선순위가 되어야한다고 생각했습니다. 그래서 저희는 신뢰할 수 있는 공공 데이터(통계청, 열린재정 등)를 기반으로 지방 재정 예산을 효율적으로 사용할 수 있는 도구를 개발해야될 필요성을 느꼈습니다.
#
#
# ### 2. 목표 및 내용
# - **목표**: 공공 데이터를 기반으로 지방 예산의 낭비를 분석하고, 절약 가능성을 시각화하여 공무원이 효율적으로 예산을 재편할 수 있도록 돕는 App 개발
# - **내용**:
#   - 지방 예산 사용 데이터를 수집하고, ML/DL 모델을 통해 이상 지출 또는 낭비 가능성이 높은 항목을 탐지
#   - 각 사업에 대한 투자 대비 효율을 분석하여 대안 제시
#   - 시각화 대시보드로 지역/사업별 집행 구조를 직관적으로 제공
#   - 사용자가 시뮬레이션을 통해 예산 재배분 결과를 시각화하여 제공
#
#
# ### 3. 주요 특징 및 핵심기술
# - **공공데이터 활용**: 열린재정, 행정안전부, 통계청 등의 신뢰성 있는 공공 데이터 기반
# - **ML/DL 분석 기술**:
#   - 이상 탐지 모델 (예: Isolation Forest, Autoencoder 등)
#   - 투자 대비 효과 예측 (예: XGBoost, LSTM 등)
# - **사용자 인터페이스**:
#   - 고민 중...
#   - 고민 중...
# - **서버 및 인프라**:
#   - 고민 중... 아마도 FastAPI는 무조건 써야될 것 같긴한데 어떤 기술로 개발해야 효율적일 지는 지호형하고 이야기를 좀 해봐야할 듯?
#
#
# ### 4. 기대효과 및 활용 방안
# - **공무원 대상**: 신뢰성있는 데이터의 AI분석을 통해 보다 효율적인 예산 분배가 가능.
# - **정책 개선**: 예산 낭비를 줄여 출산장려금, 지역 교육 등 실질적 효과가 큰 정책에 자원 재배치를 하여 지역 발전의 균형을 맞추도록 유도.
# - **지속 가능성**: 연도별·지자체별 예산 분석 결과를 축적하며 예측 모델의 정확도 향상 가능
